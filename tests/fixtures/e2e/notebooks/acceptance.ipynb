# %% [markdown]
# # Notebook Launcher acceptance fixture
# Cells are executed selectively by the end-to-end acceptance suite.

# %%
import humanize

humanize.intcomma(1234567)

# %%
sum(range(11))

# %%
raise RuntimeError('controlled fixture failure')

# %%
import time

while True:
    time.sleep(0.1)

# %%
print('x' * (2 * 1024 * 1024))

# %%
bytes(range(256))
